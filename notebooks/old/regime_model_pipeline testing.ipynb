# %%
import sys, textwrap
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None) # Show all content of each column
pd.set_option('display.width', 1000)        # Set the display width to 1000 characters

# %%
from pathlib import Path
from models.regime_model.features import prepare_feature_frame

INPUT_DIR = Path(r"C:\Users\mateo\OneDrive\Documents\algo-codex\data\raw\xls\input\regime_model\round_1")
INVENTORY_PATH = Path(r"C:\Users\mateo\OneDrive\Documents\algo-codex\data\raw\xls\input\regime_model\master_variable_inventory 20251223.xlsx")
LIQUIDITY_PATH = Path(r"C:\Users\mateo\OneDrive\Documents\algo-codex\data\raw\research\liquidity\xls\liquidity_indices_updated_20260309.xlsx")
FEAR_GREED_PATH = Path(r"C:\Users\mateo\OneDrive\Documents\algo-codex\data\raw\research\fear_greed\csv\fear_and_greed_full.csv")

featured_df, master_df, optimization_df = prepare_feature_frame(
    INPUT_DIR,
    inventory_path=INVENTORY_PATH,
    liquidity_path=LIQUIDITY_PATH,
    fear_greed_path=FEAR_GREED_PATH,
)
# Out:
# (636397, 197)

# %%
featured_df.head()
# Out:
#    Unnamed: 0  entry_collect    arimax1    arimax2  ask   atr_250  atr_ema_a  atr_ema_b   atr_ktg  atr_sma_a  atr_sma_b  atr_val  bar_m_c  bar_m_h  bar_m_l  bar_m_o  bb_low  bb_up      beta  bid     cmf   corr_1y  corr_20d     d_atr     d_avol250     d_avol5     d_avol50  d_ema100    d_ema20   d_ema200    d_ema50     d_ema8    d_natr  d_natr_ktg      d_rsi  day_open  day_range        ema      hod  hod_11am                 hod_time  intra_atr   kalmar_f  kalmar_q       kama    lod  lod_11am                 lod_time    mtd  mtd_spy  order_count  pct_chg_open         pp  premkt_m_h  premkt_m_l      premkt_m_tm  premkt_m_v  premkt_vol  prev_close  prev_high  prev_low  prev_vwap  px_10m_ago  px_11am  px_11m_ago  px_12m_ago  px_1m_ago  px_2m_ago  px_3m_ago  px_4m_ago  px_5m_ago  px_6m_ago  px_7m_ago  px_8m_ago  px_9m_ago  px_prev10  px_prev2  px_prev3  px_prev4  px_prev5  px_prev6    qtd  qtd_spy  risk_abs  risk_rel        rr1        rr2        rr3        rsi       rvol        sma  \
# ...

# %%
col_list = featured_df.columns.tolist()
print(f'variables: {len(col_list)}')
print(f'observations: {len(featured_df)}')
print(textwrap.fill(", ".join(col_list), width = 250))
# Out:
# variables:197
# observations:636397
# Unnamed: 0, entry_collect, arimax1, arimax2, ask, atr_250, atr_ema_a, atr_ema_b, atr_ktg, atr_sma_a, atr_sma_b, atr_val, bar_m_c, bar_m_h, bar_m_l, bar_m_o, bb_low, bb_up, beta, bid, cmf, corr_1y, corr_20d, d_atr, d_avol250, d_avol5, d_avol50,
# d_ema100, d_ema20, d_ema200, d_ema50, d_ema8, d_natr, d_natr_ktg, d_rsi, day_open, day_range, ema, hod, hod_11am, hod_time, intra_atr, kalmar_f, kalmar_q, kama, lod, lod_11am, lod_time, mtd, mtd_spy, order_count, pct_chg_open, pp, premkt_m_h,
# premkt_m_l, premkt_m_tm, premkt_m_v, premkt_vol, prev_close, prev_high, prev_low, prev_vwap, px_10m_ago, px_11am, px_11m_ago, px_12m_ago, px_1m_ago, px_2m_ago, px_3m_ago, px_4m_ago, px_5m_ago, px_6m_ago, px_7m_ago, px_8m_ago, px_9m_ago, px_prev10,
# ...

# %%
master_df.tail()
# Out:
#                     kite name  clean name category            code  distance              Addition
# 235  entry_collect.spy_9m_ago  spy_9m_ago      spy  extra_sym_cols      True  New feature, round_2
# 236        entry_collect.var1        var1   symbol     sym_ta_cols      True  New feature, round_2
# 237        entry_collect.var2        var2   symbol     sym_ta_cols      True  New feature, round_2
# 238         entry_collect.ytd         ytd   symbol     sym_ta_cols      True  New feature, round_2
# 239     entry_collect.ytd_spy     ytd_spy      spy  extra_sym_cols      True  New feature, round_2

# %%
optimization_df.head()
# Out:
#        clean name  optimize group subgroup
# 0     normed_date     False   NaN      NaN
# 1          symbol     False   NaN      NaN
# 2          mtm_pl     False   NaN      NaN
# 3        entry_pl     False   NaN      NaN
# 4  matched_shares     False   NaN      NaN
